# %%
import numpy as np 
import pandas as pd 
import requests
import json
import os.path
import re
import distance
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/Users/sarath/Documents/C19/CORD-19/metadata.csv")
data.head()
# Out:
#                                         sha  source_x  \
# 0                                       NaN  Elsevier
# 1                                       NaN  Elsevier
# 2                                       NaN  Elsevier
# 3  aecbc613ebdab36753235197ffb4f35734b5ca63  Elsevier
# 4                                       NaN  Elsevier
#
#                                                title  \
# 0  Intrauterine virus infections and congenital h...
# 1                  Coronaviruses in Balkan nephritis
# 2  Cigarette smoking and coronary heart disease: ...
# 3  Clinical and immunologic studies in identical ...
# 4  Epidemiology of community-acquired respiratory...
#
#                             doi pmcid  pubmed_id    license  \
# 0  10.1016/0002-8703(72)90077-4   NaN  4361535.0  els-covid
# 1  10.1016/0002-8703(80)90355-5   NaN  6243850.0  els-covid
# 2  10.1016/0002-8703(80)90356-7   NaN  7355701.0  els-covid
# 3  10.1016/0002-9343(73)90176-9   NaN  4579077.0  els-covid
# ...

# %%
data=data[data["sha"]==data["sha"]] 
data=data[data["has_full_text"]]

# %%
article = pd.read_csv("/Users/sarath/Documents/C19/CORD-19/metadata.csv")

# %%
article[(pd.notna(article['abstract'])) 
                  & (article['abstract'].str.contains("weather"))
                  & (article['abstract'].str.contains("correlation"))
                  & (article['abstract'].str.contains("virus"))].filter(["abstract","pmcid", "pubmed_id"])
# Out:
#                                                 abstract       pmcid  \
# 29512  The contribution of respiratory viruses to acu...  PMC6402941
# 36642  Objective: To understand the association betwe...  PMC1733040
#
#        pubmed_id
# 29512        NaN
# 36642        NaN

# %%
def path(shaid): 
    for dirname, _, files in os.walk('/Users/sarath/Documents'):
        if shaid+'.json' in files:
            return os.path.join(dirname,shaid+".json")

# %%
data["Path"]=data.apply(lambda x: path(x["sha"]),axis=1) 
data=data[data["Path"]==data["Path"]]
data.shape
# Out:
# (27690, 16)
